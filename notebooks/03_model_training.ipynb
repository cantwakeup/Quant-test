# %% [markdown]
# # 03 Model Training
#
# Inspect `data/processed/walk_forward_diagnostics.csv` and `data/processed/model_metrics.csv`. Confirm feature selection was done inside each training window.
