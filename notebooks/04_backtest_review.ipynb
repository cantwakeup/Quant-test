# %% [markdown]
# # 04 Backtest Review
#
# Review `data/processed/backtest.csv`, `data/processed/backtest_metrics.csv`, and `reports/equity_curve.png`. Compare strategy, buy-and-hold, index benchmark, and cash.
