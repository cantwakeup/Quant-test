# %% [markdown]
# # 01 Data Check
#
# Use `python -m src.report --config config.yaml` to generate processed CSV files, then inspect `data/processed/prices.csv`, missing values, suspensions, and adjustment assumptions here.
